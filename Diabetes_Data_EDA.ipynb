# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
Diabetes_data_df = pd.read_csv('diabetes_dataset.csv')

# %%
# Display Basic Information about the Dataset
print("\n ===Diabetes Dataset Overview=== \n")
print(f"Diabetes Dataset Loaded Shape.{Diabetes_data_df.shape}")
print(f"Columns in the Dataset: {Diabetes_data_df.columns.tolist()}")
print(f"First 5 rows of the dataset: {Diabetes_data_df.head(5)} ")
print(f"Target Dignosed of Diabates: {Diabetes_data_df.diagnosed_diabetes.nunique()}")
# Out:
#  ===Diabetes Dataset Overview===
#
# Diabetes Dataset Loaded Shape.(100000, 31)
# Columns in the Dataset: ['age', 'gender', 'ethnicity', 'education_level', 'income_level', 'employment_status', 'smoking_status', 'alcohol_consumption_per_week', 'physical_activity_minutes_per_week', 'diet_score', 'sleep_hours_per_day', 'screen_time_hours_per_day', 'family_history_diabetes', 'hypertension_history', 'cardiovascular_history', 'bmi', 'waist_to_hip_ratio', 'systolic_bp', 'diastolic_bp', 'heart_rate', 'cholesterol_total', 'hdl_cholesterol', 'ldl_cholesterol', 'triglycerides', 'glucose_fasting', 'glucose_postprandial', 'insulin_level', 'hba1c', 'diabetes_risk_score', 'diabetes_stage', 'diagnosed_diabetes']
# First 5 rows of the dataset:    age  gender ethnicity education_level  income_level employment_status  \
# 0   58    Male     Asian      Highschool  Lower-Middle          Employed
# 1   48  Female     White      Highschool        Middle          Employed
# ...

# %%
print("\n ===Basic Information about the Dataset=== \n")
print(f"Dataset Information: {Diabetes_data_df.info()} ")
# Out:
#  ===Basic Information about the Dataset===
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 31 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   age                                 100000 non-null  int64
#  1   gender                              100000 non-null  object
#  2   ethnicity                           100000 non-null  object
#  3   education_level                     100000 non-null  object
#  4   income_level                        100000 non-null  object
#  5   employment_status                   100000 non-null  object
#  6   smoking_status                      100000 non-null  object
#  7   alcohol_consumption_per_week        100000 non-null  int64
#  8   physical_activity_minutes_per_week  100000 non-null  int64
#  9   diet_score                          100000 non-null  float64
# ...

# %%
print("\n ===Statistical Summary of the Dataset=== \n")
print(f"Statistical Summary: {Diabetes_data_df.describe()}")
# Out:
#  ===Statistical Summary of the Dataset===
#
# Statistical Summary:                 age  alcohol_consumption_per_week  \
# count  100000.00000                 100000.000000
# mean       50.12041                      2.003670
# std        15.60460                      1.417779
# min        18.00000                      0.000000
# 25%        39.00000                      1.000000
# 50%        50.00000                      2.000000
# 75%        61.00000                      3.000000
# max        90.00000                     10.000000
#
#        physical_activity_minutes_per_week     diet_score  sleep_hours_per_day  \
# count                       100000.000000  100000.000000        100000.000000
# mean                           118.911640       5.994787             6.997818
# std                             84.409662       1.780954             1.094622
# min                              0.000000       0.000000             3.000000
# ...

# %%
# Check For Missing Values
print("\n ===Missing Values in the Dataset=== \n")
print(Diabetes_data_df.isnull().sum())
# Out:
#  ===Missing Values in the Dataset===
#
# age                                   0
# gender                                0
# ethnicity                             0
# education_level                       0
# income_level                          0
# employment_status                     0
# smoking_status                        0
# alcohol_consumption_per_week          0
# physical_activity_minutes_per_week    0
# diet_score                            0
# sleep_hours_per_day                   0
# screen_time_hours_per_day             0
# family_history_diabetes               0
# hypertension_history                  0
# cardiovascular_history                0
# bmi                                   0
# waist_to_hip_ratio                    0
# systolic_bp                           0
# diastolic_bp                          0
# heart_rate                            0
# cholesterol_total                     0
# hdl_cholesterol                       0
# ...

# %%
# 1. Distribution of Dignosed Diabetes
print("\n ===Distribution of Diagnosed Diabetes=== \n")
print("\n Number of Unique Values in Dignosed Diabetes: ",Diabetes_data_df['diagnosed_diabetes'].value_counts())
print("\n precentage distribution of diagnosed diabetes: \n", Diabetes_data_df['diagnosed_diabetes'].value_counts(normalize=True) * 100) 
plt.figure(figsize=(6,4))
sns.countplot(x='diagnosed_diabetes', data=Diabetes_data_df, palette='Set2')
plt.title('Distribution of Diagnosed Diabetes')
plt.xlabel('Diagnosed Diabetes (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.show()
# Out:
#  ===Distribution of Diagnosed Diabetes===
#
#
#  Number of Unique Values in Dignosed Diabetes:  diagnosed_diabetes
# 1    59998
# 0    40002
# Name: count, dtype: int64
#
#  precentage distribution of diagnosed diabetes:
#  diagnosed_diabetes
# 1    59.998
# 0    40.002
# Name: proportion, dtype: float64
# /tmp/ipykernel_2496/3757801651.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='diagnosed_diabetes', data=Diabetes_data_df, palette='Set2')

# %%
# 1. Gender vs Diagnosed Diabetes
print("\n ===Gender vs Diagnosed Diabetes=== \n")  
print("\n precentage distribution of Gender: \n", Diabetes_data_df['gender'].value_counts(normalize=True) * 100)
plt.figure(figsize=(6,4))
sns.countplot(x='gender', hue='diagnosed_diabetes', data=Diabetes_data_df, palette='Set1')
plt.title('Gender vs Diagnosed Diabetes')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Diagnosed Diabetes', labels=['No', 'Yes'])
plt.show()

# Group by ethnicity and diagnosed_diabetes to get both counts and percentages
grouped = Diabetes_data_df.groupby(['gender', 'diagnosed_diabetes'])

# Count the number of data points in each group
count_df = grouped.size().reset_index(name='count')

# Calculate percentage
count_df['percentage'] = (
    count_df['count'] / count_df.groupby('gender')['count'].transform('sum') * 100
)

# Display the table
print(count_df.to_string(index=False))
# Out:
#  ===Gender vs Diagnosed Diabetes===
#
#
#  precentage distribution of Gender:
#  gender
# Female    50.216
# Male      47.771
# Other      2.013
# Name: proportion, dtype: float64
# gender  diagnosed_diabetes  count  percentage
# Female                   0  20164   40.154532
# Female                   1  30052   59.845468
#   Male                   0  19077   39.934270
#   Male                   1  28694   60.065730
#  Other                   0    761   37.804272
#  Other                   1   1252   62.195728

# %%
#2. Ethnicity vs Diagnosed Diabetes
print("\n === Ethnicity vs Diagnosed Diabetes=== \n")   
print("\n precentage distribution of Ethnicity: \n", Diabetes_data_df['ethnicity'].value_counts(normalize=True) * 100)
plt.figure(figsize=(10,6))
sns.countplot(x='ethnicity', hue='diagnosed_diabetes', data=Diabetes_data_df, palette='Set3')
plt.title('Ethnicity vs Diagnosed Diabetes')
plt.xlabel('Ethnicity')
plt.ylabel('Count')
plt.legend(title='Diagnosed Diabetes', labels=['No', 'Yes'])
plt.xticks(rotation=45)
plt.show()

# Group by ethnicity and diagnosed_diabetes to get both counts and percentages
grouped = Diabetes_data_df.groupby(['ethnicity', 'diagnosed_diabetes'])

# Count the number of data points in each group
count_df = grouped.size().reset_index(name='count')

# Calculate percentage
count_df['percentage'] = (
    count_df['count'] / count_df.groupby('ethnicity')['count'].transform('sum') * 100
)

# Display the table
print(count_df.to_string(index=False))
# Out:
#  === Ethnicity vs Diagnosed Diabetes===
#
#
#  precentage distribution of Ethnicity:
#  ethnicity
# White       44.997
# Hispanic    20.103
# Black       17.986
# Asian       11.865
# Other        5.049
# Name: proportion, dtype: float64
# ethnicity  diagnosed_diabetes  count  percentage
#     Asian                   0   4737   39.924147
#     Asian                   1   7128   60.075853
#     Black                   0   7169   39.858779
#     Black                   1  10817   60.141221
#  Hispanic                   0   8163   40.605880
#  Hispanic                   1  11940   59.394120
#     Other                   0   1981   39.235492
#     Other                   1   3068   60.764508
#     White                   0  17952   39.895993
#     White                   1  27045   60.104007

# %%
# 3. Education Level vs Diagnosed Diabetes
print("\n ===Education Level vs Diagnosed Diabetes=== \n")    
print("\n precentage distribution of Education Level: \n", Diabetes_data_df['education_level'].value_counts(normalize=True) * 100)    
plt.figure(figsize=(10,6))
sns.countplot(x='education_level', hue='diagnosed_diabetes', data=Diabetes_data_df, palette='Set2')
plt.title('Education Level vs Diagnosed Diabetes')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.legend(title='Diagnosed Diabetes', labels=['No', 'Yes'])
plt.xticks(rotation=45)
plt.show()

# Group by Education Level and diagnosed_diabetes to get both counts and percentages
grouped = Diabetes_data_df.groupby(['education_level', 'diagnosed_diabetes'])

# Count the number of data points in each group
count_df = grouped.size().reset_index(name='count')

# Calculate percentage
count_df['percentage'] = (
    count_df['count'] / count_df.groupby('education_level')['count'].transform('sum') * 100
)

# Display the table
print(count_df.to_string(index=False))
# Out:
#  ===Education Level vs Diagnosed Diabetes===
#
#
#  precentage distribution of Education Level:
#  education_level
# Highschool      44.891
# Graduate        35.037
# Postgraduate    14.972
# No formal        5.100
# Name: proportion, dtype: float64
# education_level  diagnosed_diabetes  count  percentage
#        Graduate                   0  13973   39.880698
#        Graduate                   1  21064   60.119302
#      Highschool                   0  17926   39.932280
#      Highschool                   1  26965   60.067720
#       No formal                   0   2017   39.549020
#       No formal                   1   3083   60.450980
#    Postgraduate                   0   6086   40.649212
#    Postgraduate                   1   8886   59.350788

# %%
# 4. Income vs Diagnosed Diabetes
print("\n ===Income vs Diagnosed Diabetes=== \n")
print("\n precentage distribution of Income Level: \n", Diabetes_data_df['income_level'].value_counts(normalize=True) * 100)    
plt.figure(figsize=(10,6))
sns.countplot(x='income_level', hue='diagnosed_diabetes', data=Diabetes_data_df, palette='Set1')
plt.title('Income Level vs Diagnosed Diabetes')
plt.xlabel('Income Level')
plt.ylabel('Count')
plt.legend(title='Diagnosed Diabetes', labels=['No', 'Yes'])
plt.xticks(rotation=45)
plt.show() 

# Group by Income and diagnosed_diabetes to get both counts and percentages
grouped = Diabetes_data_df.groupby(['income_level', 'diagnosed_diabetes'])

# Count the number of data points in each group
count_df = grouped.size().reset_index(name='count')

# Calculate percentage
count_df['percentage'] = (
    count_df['count'] / count_df.groupby('income_level')['count'].transform('sum') * 100
)

# Display the table
print(count_df.to_string(index=False))
# Out:
#  ===Income vs Diagnosed Diabetes===
#
#
#  precentage distribution of Income Level:
#  income_level
# Middle          35.152
# Lower-Middle    25.150
# Upper-Middle    19.866
# Low             14.830
# High             5.002
# Name: proportion, dtype: float64
# income_level  diagnosed_diabetes  count  percentage
#         High                   0   1965   39.284286
#         High                   1   3037   60.715714
#          Low                   0   5924   39.946055
#          Low                   1   8906   60.053945
# Lower-Middle                   0   9963   39.614314
# Lower-Middle                   1  15187   60.385686
#       Middle                   0  14177   40.330564
#       Middle                   1  20975   59.669436
# Upper-Middle                   0   7973   40.133897
# Upper-Middle                   1  11893   59.866103

# %%
# 5.Employement Status vs Diagnosed Diabetes
print("\n ===Employment Status vs Diagnosed Diabetes=== \n")  
print("\n precentage distribution of Income Level: \n", Diabetes_data_df['employment_status'].value_counts(normalize=True) * 100)         
plt.figure(figsize=(10,6))
sns.countplot(x='employment_status', hue='diagnosed_diabetes', data=Diabetes_data_df, palette='Set3')
plt.title('Employment Status vs Diagnosed Diabetes')
plt.xlabel('Employment Status')
plt.ylabel('Count')
plt.legend(title='Diagnosed Diabetes', labels=['No', 'Yes'])
plt.xticks(rotation=45)
plt.show()

# Group by Employment Statues  and diagnosed_diabetes to get both counts and percentages
grouped = Diabetes_data_df.groupby(['employment_status', 'diagnosed_diabetes'])

# Count the number of data points in each group
count_df = grouped.size().reset_index(name='count')

# Calculate percentage
count_df['percentage'] = (
    count_df['count'] / count_df.groupby('employment_status')['count'].transform('sum') * 100
)

# Display the table
print(count_df.to_string(index=False))
# Out:
#  ===Employment Status vs Diagnosed Diabetes===
#
#
#  precentage distribution of Income Level:
#  employment_status
# Employed      60.175
# Retired       21.761
# Unemployed    11.918
# Student        6.146
# Name: proportion, dtype: float64
# employment_status  diagnosed_diabetes  count  percentage
#          Employed                   0  23979   39.848774
#          Employed                   1  36196   60.151226
#           Retired                   0   8807   40.471486
#           Retired                   1  12954   59.528514
#           Student                   0   2475   40.270094
#           Student                   1   3671   59.729906
#        Unemployed                   0   4741   39.780164
#        Unemployed                   1   7177   60.219836

# %%
# 6. Smoking Status vs Diagnosed Diabetes
print("\n ===Smoking Status vs Diagnosed Diabetes=== \n")
print("\n precentage distribution of Income Level: \n", Diabetes_data_df['smoking_status'].value_counts(normalize=True) * 100)                
plt.figure(figsize=(10,6))
sns.countplot(x='smoking_status', hue='diagnosed_diabetes', data=Diabetes_data_df, palette='Set2')
plt.title('Smoking Status vs Diagnosed Diabetes')
plt.xlabel('Smoking Status')
plt.ylabel('Count')
plt.legend(title='Diagnosed Diabetes', labels=['No', 'Yes'])
plt.show()

# Group by Smoking  Statues  and diagnosed_diabetes to get both counts and percentages
grouped = Diabetes_data_df.groupby(['smoking_status', 'diagnosed_diabetes'])

# Count the number of data points in each group
count_df = grouped.size().reset_index(name='count')

# Calculate percentage
count_df['percentage'] = (
    count_df['count'] / count_df.groupby('smoking_status')['count'].transform('sum') * 100
)

# Display the table
print(count_df.to_string(index=False))
# Out:
#  ===Smoking Status vs Diagnosed Diabetes===
#
#
#  precentage distribution of Income Level:
#  smoking_status
# Never      59.813
# Current    20.176
# Former     20.011
# Name: proportion, dtype: float64
# smoking_status  diagnosed_diabetes  count  percentage
#        Current                   0   8069   39.993061
#        Current                   1  12107   60.006939
#         Former                   0   7982   39.888062
#         Former                   1  12029   60.111938
#          Never                   0  23951   40.043134
#          Never                   1  35862   59.956866

# %% [markdown]
# #### Catagorical Veriables Correlation

# %%
def cramers_v(x, y):
    """Calculate Cramér's V statistic for categorical-categorical association."""
    confusion_matrix = pd.crosstab(x, y)
    chi2 = stats.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1)) / (n-1))
    rcorr = r - ((r-1)**2) / (n-1)
    kcorr = k - ((k-1)**2) / (n-1)
    return np.sqrt(phi2corr / min((kcorr-1), (rcorr-1)))

# Example: Compute for all categorical variables vs target
target = 'diagnosed_diabetes'
categorical_cols = Diabetes_data_df.select_dtypes(include='object').columns.tolist()

corr_results = {}
for col in categorical_cols:
    corr_results[col] = cramers_v(Diabetes_data_df[col], Diabetes_data_df[target])

# Convert to DataFrame
corr_df = pd.DataFrame(list(corr_results.items()), columns=['Variable', 'CramersV']).sort_values(by='CramersV', ascending=False)

# Set figure size and style
plt.figure(figsize=(10, 6))
bars = plt.barh(
    corr_df['Variable'],
    corr_df['CramersV'],
    color=plt.cm.viridis(corr_df['CramersV'] / corr_df['CramersV'].max())
)

# Add value labels next to each bar
for bar in bars:
    width = bar.get_width()
    plt.text(width + 0.01,               # small offset to the right
             bar.get_y() + bar.get_height()/2,
             f"{width:.2f}",
             va='center', fontsize=10, color='black')

# Titles and labels
plt.title("Categorical Variables vs Diagnosed Diabetes (Cramér’s V)", fontsize=14, fontweight='bold')
plt.xlabel("Cramér’s V (Association Strength)", fontsize=12)
plt.ylabel("Categorical Variable", fontsize=12)

# Grid and layout
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.xlim(0, 1)  # since Cramér’s V ranges 0–1
plt.gca().invert_yaxis()  # keep strongest on top
plt.tight_layout()

plt.show()

# %% [markdown]
# #### Numaric Columns Correlations

# %%
# Numerical Column Correlations
numerical_cols = Diabetes_data_df.select_dtypes(include=['int64', 'float64']).columns
correlation_matrix = Diabetes_data_df[numerical_cols].corr()
plt.figure(figsize=(20,10))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True)
plt.title('Correlation Matrix of Numerical Features')
plt.xticks(
    range(len(correlation_matrix.columns)),
    correlation_matrix.columns,
    rotation=90,
    fontsize=8
)
plt.yticks(
    range(len(correlation_matrix.columns)),
    correlation_matrix.columns,
    fontsize=8
)

# Add gridlines for clarity
plt.grid(False)
plt.tight_layout()
plt.show()

# %%
# Select only numerical columns
numerical_cols = Diabetes_data_df.select_dtypes(include=['int64', 'float64']).columns

# Compute correlation matrix
correlation_matrix = Diabetes_data_df[numerical_cols].corr()

# Mask the diagonal and upper triangle
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

# Plot heatmap without diagonal
plt.figure(figsize=(20,10))
sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt=".2f",
    cmap='coolwarm',
    square=True,
    mask=mask
)

plt.title('Correlation Matrix of Numerical Features (without Diagonal)')
plt.xticks(
    range(len(correlation_matrix.columns)),
    correlation_matrix.columns,
    rotation=90,
    fontsize=8
)
plt.yticks(
    range(len(correlation_matrix.columns)),
    correlation_matrix.columns,
    fontsize=8
)
# Out:
# ([<matplotlib.axis.YTick at 0x73c547d163c0>,
# ...
#  [Text(0, 0, 'age'),
#   Text(0, 1, 'alcohol_consumption_per_week'),
#   Text(0, 2, 'physical_activity_minutes_per_week'),
#   Text(0, 3, 'diet_score'),
#   Text(0, 4, 'sleep_hours_per_day'),
#   Text(0, 5, 'screen_time_hours_per_day'),
#   Text(0, 6, 'family_history_diabetes'),
#   Text(0, 7, 'hypertension_history'),
#   Text(0, 8, 'cardiovascular_history'),
#   Text(0, 9, 'bmi'),
#   Text(0, 10, 'waist_to_hip_ratio'),
#   Text(0, 11, 'systolic_bp'),
#   Text(0, 12, 'diastolic_bp'),
#   Text(0, 13, 'heart_rate'),
#   Text(0, 14, 'cholesterol_total'),
#   Text(0, 15, 'hdl_cholesterol'),
#   Text(0, 16, 'ldl_cholesterol'),
#   Text(0, 17, 'triglycerides'),
#   Text(0, 18, 'glucose_fasting'),
#   Text(0, 19, 'glucose_postprandial'),
#   Text(0, 20, 'insulin_level'),
#   Text(0, 21, 'hba1c'),
#   Text(0, 22, 'diabetes_risk_score'),
#   Text(0, 23, 'diagnosed_diabetes')])

# %% [markdown]
# #### Correlation of Numarical Columns With Target Column [Dignostioc Od Dibatics]

# %%
# Correlation Numarical Columns Vs Dignostioc Od Dibatics 
correlation_with_target = correlation_matrix['diagnosed_diabetes'].drop('diagnosed_diabetes')
print("\n ===Correlation of Numerical Columns With Target Column [Diagnosed Diabetes]=== \n")
print(correlation_with_target.sort_values(ascending=False))
# Out:
#  ===Correlation of Numerical Columns With Target Column [Diagnosed Diabetes]===
#
# hba1c                                 0.679397
# glucose_postprandial                  0.629832
# glucose_fasting                       0.510919
# diabetes_risk_score                   0.277300
# family_history_diabetes               0.197926
# age                                   0.137713
# bmi                                   0.097057
# systolic_bp                           0.095481
# waist_to_hip_ratio                    0.078918
# ldl_cholesterol                       0.067475
# cholesterol_total                     0.058173
# insulin_level                         0.057715
# triglycerides                         0.056230
# diastolic_bp                          0.035619
# cardiovascular_history                0.029793
# hypertension_history                  0.027524
# heart_rate                            0.022785
# screen_time_hours_per_day             0.018127
# ...

# %%
# Sort The Correlation Values
Dibetes_corr_sorted = correlation_with_target.sort_values(ascending=False)

#Bottom 6 Correlation Columns
print("\n ===Bottom 6 Correlation Columns With Diagnosed Diabetes=== \n")
bottom6_corr_Diagnosed_Diabetes = Dibetes_corr_sorted.tail(6)
print(bottom6_corr_Diagnosed_Diabetes)
# Out:
#  ===Bottom 6 Correlation Columns With Diagnosed Diabetes===
#
# screen_time_hours_per_day             0.018127
# alcohol_consumption_per_week          0.000760
# sleep_hours_per_day                  -0.000399
# diet_score                           -0.044298
# hdl_cholesterol                      -0.051227
# physical_activity_minutes_per_week   -0.100774
# Name: diagnosed_diabetes, dtype: float64

# %%
#Top 6 Correlation Columns
print("\n ===Top 6 Correlation Columns With Diagnosed Diabetes=== \n")
top6_corr_Diagnosed_Diabetes = Dibetes_corr_sorted.head(6)
print(top6_corr_Diagnosed_Diabetes)
# Out:
#  ===Top 6 Correlation Columns With Diagnosed Diabetes===
#
# hba1c                      0.679397
# glucose_postprandial       0.629832
# glucose_fasting            0.510919
# diabetes_risk_score        0.277300
# family_history_diabetes    0.197926
# age                        0.137713
# Name: diagnosed_diabetes, dtype: float64

# %%
plt.figure(figsize=(12, 8))  # bigger figure for readability
correlation_with_target.plot(kind='bar', color='teal')

plt.title('Correlation of Numeric Features with Diagnosed Diabetes (yes/no)', fontsize=14, pad=15)
plt.ylabel('Correlation Coefficient', fontsize=12)
plt.xticks(rotation=90, fontsize=9)
plt.yticks(fontsize=10)

plt.tight_layout()
plt.show()

# %%
top_n = 6
top_features = correlation_with_target.head(top_n).index.tolist() + ['diagnosed_diabetes']

# Create pairplot for top features
sns.pairplot(Diabetes_data_df[top_features], diag_kind='kde', corner=True)
plt.suptitle(f'Pair Plot: Top {top_n} Features vs Diagnosed Diabetes', fontsize=14, y=1.02)
plt.show()

# %%
# Top 6 Correlation Columns KDE Plots with Diagnosed Diabetes
print("\n ===Top 6 Correlation Columns KDE Plots with Diagnosed Diabetes=== \n")       
plt.figure(figsize=(15, 10))
for i, col in enumerate(top6_corr_Diagnosed_Diabetes.index):
    plt.subplot(2, 3, i + 1)
    sns.kdeplot(data=Diabetes_data_df, x=col, hue='diagnosed_diabetes', fill=True, common_norm=False, palette='Set2', alpha=0.5)
    plt.title(f'KDE Plot of {col} by Diagnosed Diabetes')
    plt.xlabel(col)
    plt.ylabel('Density')
plt.tight_layout()
plt.show()
# Out:
#  ===Top 6 Correlation Columns KDE Plots with Diagnosed Diabetes===

# %% [markdown]
# ## One Hot Encoding the Catagorical Veriables And Check the Correlation With Target[ Diagnosed Diabetes]

# %%
# One Hot Encoding the Catagorical Veriables And Check the Correlation With Target[ Diagnosed Diabetes]
print("\n ===One Hot Encoding the Catagorical Veriables And Check the Correlation With Target[ Diagnosed Diabetes]=== \n")       
categorical_cols = Diabetes_data_df.select_dtypes(include='object').columns
Diabetes_data_encoded = pd.get_dummies(Diabetes_data_df, columns=categorical_cols, drop_first=True)
correlation_matrix_encoded = Diabetes_data_encoded.corr()
correlation_with_target_encoded = correlation_matrix_encoded['diagnosed_diabetes'].drop('diagnosed_diabetes')
correlation_with_target_encoded_sorted = correlation_with_target_encoded.sort_values(ascending=False)
print(correlation_with_target_encoded_sorted)
# Out:
#  ===One Hot Encoding the Catagorical Veriables And Check the Correlation With Target[ Diagnosed Diabetes]===
#
# diabetes_stage_Type 2                 0.995349
# hba1c                                 0.679397
# glucose_postprandial                  0.629832
# glucose_fasting                       0.510919
# diabetes_risk_score                   0.277300
# family_history_diabetes               0.197926
# age                                   0.137713
# bmi                                   0.097057
# systolic_bp                           0.095481
# waist_to_hip_ratio                    0.078918
# ldl_cholesterol                       0.067475
# cholesterol_total                     0.058173
# insulin_level                         0.057715
# triglycerides                         0.056230
# diastolic_bp                          0.035619
# cardiovascular_history                0.029793
# hypertension_history                  0.027524
# heart_rate                            0.022785
# ...

# %%
mask = np.triu(np.ones_like(correlation_matrix_encoded, dtype=bool))

plt.figure(figsize=(18, 14))  # larger canvas

# Plot heatmap
sns.heatmap(
    correlation_matrix_encoded,
    mask=mask,
    cmap='coolwarm',
    annot=True,
    fmt=".2f",
    square=True,
    linewidths=0.5,
    annot_kws={"size": 8},  # smaller text inside boxes
    cbar_kws={"shrink": 0.8, "label": "Correlation Coefficient"}
)

# Title
plt.title(
    'Correlation Matrix of Encoded Numerical Features (Upper Triangle)',
    fontsize=18,
    fontweight='bold',
    pad=25
)

# X-axis labels
plt.xticks(
    rotation=45,        # angled to prevent overlap
    ha='right',         # align to right edge
    fontsize=9
)

# Y-axis labels
plt.yticks(
    rotation=0,         # keep readable horizontally
    fontsize=9
)

# Adjust spacing around the heatmap
plt.subplots_adjust(left=0.25, bottom=0.25, right=0.95, top=0.9)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 8))  # Wider for longer feature names

# Sort correlations by absolute value (optional but helps readability)
correlation_sorted_target = correlation_with_target_encoded.sort_values(ascending=False)

# Plot
plt.figure(figsize=(18, 9))  # wider for long labels
ax = plt.gca()

# --- Bar plot ---
ax.bar(
    correlation_sorted_target.index,
    correlation_sorted_target.values,
    color=['#1f77b4' if val > 0 else '#d62728' for val in correlation_sorted_target],
    edgecolor='black',
    alpha=0.8,
    label='Feature Correlation (Bar)'
)

# --- Line plot overlay ---
ax.plot(
    np.arange(len(correlation_sorted_target)),
    correlation_sorted_target.values,
    color='darkorange',
    linewidth=2.5,
    marker='o',
    markersize=6,
    label='Correlation Trend (Line)'
)

# --- Title & axis labels ---
ax.set_title(
    'Correlation of Features with Diagnosed Diabetes (Yes/No)',
    fontsize=18,
    fontweight='bold',
    pad=25
)
ax.set_ylabel('Correlation Coefficient', fontsize=13)
ax.set_xlabel('Features', fontsize=13)

# --- Improve X-axis readability ---
ax.set_xticks(np.arange(len(correlation_sorted_target)))
ax.set_xticklabels(
    correlation_sorted_target.index,
    rotation=45,      # tilt labels
    ha='right',       # align to prevent overlap
    fontsize=10
)

# --- Grid and layout tweaks ---
ax.grid(axis='y', linestyle='--', alpha=0.7)
ax.legend(fontsize=11, loc='upper right')

# Add spacing around the figure
plt.subplots_adjust(bottom=0.3, left=0.08, right=0.97, top=0.9)
plt.tight_layout()
plt.show()

# %%
correlation_sorted_target.index
# Out:
# Index(['diabetes_stage_Type 2', 'hba1c', 'glucose_postprandial',
#        'glucose_fasting', 'diabetes_risk_score', 'family_history_diabetes',
#        'age', 'bmi', 'systolic_bp', 'waist_to_hip_ratio', 'ldl_cholesterol',
#        'cholesterol_total', 'insulin_level', 'triglycerides', 'diastolic_bp',
#        'cardiovascular_history', 'hypertension_history', 'heart_rate',
#        'screen_time_hours_per_day', 'gender_Other',
#        'income_level_Lower-Middle', 'ethnicity_Other',
#        'education_level_No formal', 'ethnicity_White',
#        'employment_status_Unemployed', 'ethnicity_Black', 'gender_Male',
#        'education_level_Highschool', 'smoking_status_Former',
#        'alcohol_consumption_per_week', 'income_level_Low',
#        'sleep_hours_per_day', 'smoking_status_Never',
#        'income_level_Upper-Middle', 'employment_status_Student',
#        'diabetes_stage_Type 1', 'income_level_Middle',
#        'employment_status_Retired', 'education_level_Postgraduate',
# ...

# %%
## Diabetes_data_df One Hot Encoded Dataframe
Diabetes_data_df_one = pd.get_dummies(Diabetes_data_df, columns=categorical_cols, drop_first=True) 
Diabetes_data_df_one.head(5) 
Diabetes_data_df_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 46 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   age                                 100000 non-null  int64
#  1   alcohol_consumption_per_week        100000 non-null  int64
#  2   physical_activity_minutes_per_week  100000 non-null  int64
#  3   diet_score                          100000 non-null  float64
#  4   sleep_hours_per_day                 100000 non-null  float64
#  5   screen_time_hours_per_day           100000 non-null  float64
#  6   family_history_diabetes             100000 non-null  int64
#  7   hypertension_history                100000 non-null  int64
#  8   cardiovascular_history              100000 non-null  int64
#  9   bmi                                 100000 non-null  float64
#  10  waist_to_hip_ratio                  100000 non-null  float64
# ...

# %%
import math


print("\n=== KDE Plots of Features by Diagnosed Diabetes ===\n")

# Get the sorted list of features
features = correlation_sorted_target.index.tolist()

# Keep only features that are actually in the dataframe and numeric
valid_features = [col for col in features if col in Diabetes_data_df_one.columns and pd.api.types.is_numeric_dtype(Diabetes_data_df_one[col])]

# Calculate subplot grid dynamically (3 columns per row)
cols = 3
rows = math.ceil(len(valid_features) / cols)

plt.figure(figsize=(18, rows * 4))

for i, col in enumerate(valid_features):
    plt.subplot(rows, cols, i + 1)
    sns.kdeplot(
        data=Diabetes_data_df_one,
        x=col,
        hue='diagnosed_diabetes',
        fill=True,
        common_norm=False,
        palette='Set2',
        alpha=0.5,
        linewidth=1.5
    )
    plt.title(f'{col} vs Diagnosed Diabetes', fontsize=12, fontweight='bold')
    plt.xlabel(col, fontsize=10)
    plt.ylabel('Density', fontsize=10)
    plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

print(f"\n✅ Plotted {len(valid_features)} features successfully. Skipped {len(features) - len(valid_features)} missing/non-numeric columns.")
# Out:
# === KDE Plots of Features by Diagnosed Diabetes ===
# /tmp/ipykernel_33148/2781652304.py:20: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# /tmp/ipykernel_33148/2781652304.py:20: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# /tmp/ipykernel_33148/2781652304.py:20: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# ✅ Plotted 45 features successfully. Skipped 0 missing/non-numeric columns.
